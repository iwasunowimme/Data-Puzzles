# %% [markdown]
# # Problem summary
#
# Can you find the silhouette hidden in this dataset?

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/hyperc54/data-puzzles-assets/master/visualisation/chal1/chal_visu_1_q2_data.csv')
df.head()
# Out:
#     feature_0   feature_1   feature_2   feature_3   feature_4   feature_5  \
# 0  311.501194 -434.375063  465.724596  -13.756244   63.154977 -293.572478
# 1  278.741781 -553.400130  276.383054   48.562182   42.452864 -368.840239
# 2  416.016118 -643.424492  367.760502  131.633500   23.159960 -366.994592
# 3  267.473168 -759.908836  336.770534   79.037171  104.378434 -175.572765
# 4  333.826916 -740.880883  245.520497  -31.536664   27.130920 -573.016784
#
#    feature_6
# 0 -74.132678
# 1 -74.595382
# 2 -77.408354
# 3 -74.561150
# 4 -73.475911

# %% [markdown]
# # Your turn!
#
# Just to start lets have a small look at the features compared to one another in a pair-plot

# %%
import seaborn as sns
sns.pairplot(df);

# %% [markdown]
# We can see that there is an image forming with feature_2 and feature_5 so we can look at just this comparison.
# Something to also note is that every other feature follows a normal distribution pattern.

# %%
plt.scatter(df.feature_2, df.feature_5);

# %% [markdown]
# Behold a unicorn, lets make it bigger to see it in all its glory.

# %%
plt.figure(figsize=(15,15))
plt.scatter(df.feature_2, df.feature_5);

# %% [markdown]
# # Problem statement
#
# Can you find the last keyword hidden in that dataset?

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/hyperc54/data-puzzles-assets/master/visualisation/chal1/chal_visu_1_q3_data.csv')

df.head()
# Out:
#            x          y  mystery_feature
# 0  31.950806 -77.874664               77
# 1  22.000000 -36.022263              104
# 2  28.500002 -66.546692               10
# 3  25.923157 -69.759354               24
# 4  30.458435 -88.715622               96

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
plt.scatter(df.x,df.y)

# %%
import seaborn as sns
sns.pairplot(df);

# %% [markdown]
# I can see some straight lines and voids when comparing x or y to myster_feature, so want to take a look a that

# %%
plt.figure(figsize=(15,15))
plt.scatter(df.x,df.mystery_feature)

# %%
plt.figure(figsize=(15,15))
plt.scatter(df.y,df.mystery_feature)

# %% [markdown]
# can see some basic patterns and structures to the graphs, i wonder what they look like overlayed

# %%
print(max(df.x))
print(min(df.x))
print(max(df.y))
print(min(df.y))
print(max(df.mystery_feature))
print(min(df.mystery_feature))
print(df.shape)
# Out:
# 39.98651123046875
# 0.01910400390625
# -0.0
# -90.87916564941408
# 121
# 0
# (5600, 3)

# %%
figure = plt.figure(figsize=(15,15))
plt.scatter([9*x for x in df.x],df.mystery_feature)
plt.scatter([-4*x for x in df.y],df.mystery_feature)
plt.show()

# %%
figure = plt.figure(figsize=(15,15))
plt.scatter([2.22*x for x in df.x],df.mystery_feature)
plt.scatter([x + 90 for x in df.y],df.mystery_feature)
plt.show()

# %%
figure = plt.figure(figsize=(15,15))
plt.scatter([3*x for x in df.x],[x for x in df.mystery_feature])
plt.scatter([1*x for x in df.mystery_feature],[-1.3333*x for x in df.y])
plt.show()

# %% [markdown]
# Overlaid it does not look like much, over laid by flipping the y, increasing the y, then rotating it.
# Did not see anything resembling words, shape, or pattern

# %%
mult_df = df.copy() # Create a deep copy to ammend

# %%
figure = plt.figure(figsize=(15,15))
plt.scatter(mult_df.x*mult_df.mystery_feature, mult_df.y*mult_df.mystery_feature)

# %%
for i in range(121):
    figure = plt.figure(figsize=(1,1))
    for index, row in df.iterrows():
        if(row.mystery_feature == i):
            plt.scatter(row.x, row.y )
# Out:
# C:\Users\iwimme\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
